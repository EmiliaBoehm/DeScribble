# %%
import sys
sys.path.append('../src')
sys.path.append('../src/Imagehandling/')
sys.path.append('../src/Imagehandling/Img')
from Imagehandling.core import Img

# %%
BILD_DUNKLER_RAND="/home/jv/Bilder/010.jpeg"
BILD_BEIGE="/home/jv/Bilder/014.jpeg"
BILD_BUNTER_RAND="/home/jv/Bilder/016.jpg"
BILD_GUT="/home/jv/Bilder/testdokument_009.png"

img = Img(BILD_BUNTER_RAND)
img.binarize().morph_dilate().morph_open().find_contours()
img.show();
img.show_transformations();
# Out:
# Image size (2000, 1333), using kernel (200, 13)
# Image size (2000, 1333), using kernel (5, 5)
